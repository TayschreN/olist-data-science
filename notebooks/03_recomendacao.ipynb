# %% [markdown]
# # Sistema de Recomendação

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.etl import load_raw_data, merge_datasets
from src.recommender import (
    recommend_by_category,
    recommend_for_customer,
    create_user_item_matrix,
)

sns.set_theme()

# %%
data = load_raw_data()
df = merge_datasets(data)

# Recomendar para um cliente específico
sample_customer = df['customer_unique_id'].iloc[0]
recs = recommend_for_customer(df, sample_customer, top_n=5)
recs
